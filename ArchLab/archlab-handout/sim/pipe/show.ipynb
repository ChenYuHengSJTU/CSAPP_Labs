# %%
# !make clean
# !make psim VERSION=full

# %%
# !cp ncopy-copy-2.ys ncopy.ys
# !make drivers
# !./benchmark.pl
# !./correctness.pl
# Out:
# ./gen-driver.pl -n 4 -f ncopy.ys > sdriver.ys
# ../misc/yas sdriver.ys
# ./gen-driver.pl -n 63 -f ncopy.ys > ldriver.ys
# ../misc/yas ldriver.ys
# 	ncopy
# 0	13
# 1	40	40.00
# 2	61	30.50
# 3	76	25.33
# 4	94	23.50
# 5	109	21.80
# 6	124	20.67
# 7	142	20.29
# 8	160	20.00
# 9	172	19.11
# 10	190	19.00
# 11	202	18.36
# 12	232	19.33
# 13	247	19.00
# 14	262	18.71
# 15	280	18.67
# 16	289	18.06
# 17	316	18.59
# 18	322	17.89
# 19	346	18.21
# 20	367	18.35
# 21	367	17.48
# 22	388	17.64
# 23	406	17.65
# 24	421	17.54
# 25	439	17.56
# 26	451	17.35
# 27	475	17.59
# 28	505	18.04
# 29	502	17.31
# 30	517	17.23
# 31	541	17.45
# 32	553	17.28
# 33	571	17.30
# 34	598	17.59
# 35	604	17.26
# 36	631	17.53
# 37	643	17.38
# 38	649	17.08
# 39	670	17.18
# 40	691	17.27
# 41	709	17.29
# 42	715	17.02
# 43	736	17.12
# 44	766	17.41
# 45	757	16.82
# 46	790	17.17
# 47	799	17.00
# 48	835	17.40
# 49	826	16.86
# 50	853	17.06
# 51	865	16.96
# 52	868	16.69
# 53	913	17.23
# 54	928	17.19
# 55	934	16.98
# 56	958	17.11
# ...

# %%
# !cp ncopy-copy-5.ys ncopy.ys
# !make drivers
# !./benchmark.pl
# !./correctness.pl
# Out:
# ./gen-driver.pl -n 4 -f ncopy.ys > sdriver.ys
# ../misc/yas sdriver.ys
# ./gen-driver.pl -n 63 -f ncopy.ys > ldriver.ys
# ../misc/yas ldriver.ys
# 	ncopy
# 0	13
# 1	29	29.00
# 2	40	20.00
# 3	48	16.00
# 4	59	14.75
# 5	82	16.40
# 6	93	15.50
# 7	101	14.43
# 8	112	14.00
# 9	132	14.67
# 10	146	14.60
# 11	151	13.73
# 12	165	13.75
# 13	185	14.23
# 14	196	14.00
# 15	204	13.60
# 16	218	13.62
# 17	238	14.00
# 18	252	14.00
# 19	254	13.37
# 20	271	13.55
# 21	285	13.57
# 22	299	13.59
# 23	307	13.35
# 24	318	13.25
# 25	335	13.40
# 26	352	13.54
# 27	360	13.33
# 28	368	13.14
# 29	385	13.28
# 30	402	13.40
# 31	413	13.32
# 32	421	13.16
# 33	438	13.27
# 34	455	13.38
# 35	466	13.31
# 36	474	13.17
# 37	491	13.27
# 38	511	13.45
# 39	516	13.23
# 40	530	13.25
# 41	541	13.20
# 42	561	13.36
# 43	560	13.02
# 44	580	13.18
# 45	594	13.20
# 46	614	13.35
# 47	610	12.98
# 48	627	13.06
# 49	656	13.39
# 50	658	13.16
# 51	675	13.24
# 52	683	13.13
# 53	691	13.04
# 54	702	13.00
# 55	722	13.13
# 56	733	13.09
# ...

# %%
# !cp ncopy-copy-4.ys ncopy.ys
# !make drivers
# !./benchmark.pl
# !./correctness.pl
# Out:
# ./gen-driver.pl -n 4 -f ncopy.ys > sdriver.ys
# ../misc/yas sdriver.ys
# ./gen-driver.pl -n 63 -f ncopy.ys > ldriver.ys
# ../misc/yas ldriver.ys
# 	ncopy
# 0	13
# 1	32	32.00
# 2	44	22.00
# 3	53	17.67
# 4	65	16.25
# 5	90	18.00
# 6	102	17.00
# 7	111	15.86
# 8	123	15.38
# 9	149	16.56
# 10	161	16.10
# 11	170	15.45
# 12	182	15.17
# 13	204	15.69
# 14	216	15.43
# 15	225	15.00
# 16	237	14.81
# 17	263	15.47
# 18	272	15.11
# 19	284	14.95
# 20	293	14.65
# 21	315	15.00
# 22	330	15.00
# 23	339	14.74
# 24	354	14.75
# 25	374	14.96
# 26	386	14.85
# 27	398	14.74
# 28	410	14.64
# 29	432	14.90
# 30	444	14.80
# 31	450	14.52
# 32	468	14.62
# 33	494	14.97
# 34	506	14.88
# 35	512	14.63
# 36	518	14.39
# 37	549	14.84
# 38	558	14.68
# 39	567	14.54
# 40	579	14.47
# 41	605	14.76
# 42	620	14.76
# 43	623	14.49
# 44	635	14.43
# 45	669	14.87
# 46	669	14.54
# 47	675	14.36
# 48	693	14.44
# 49	716	14.61
# 50	722	14.44
# 51	734	14.39
# 52	758	14.58
# 53	780	14.72
# 54	789	14.61
# 55	801	14.56
# 56	798	14.25
# ...

# %%
# !cp ncopy-copy-7.ys ncopy.ys
# !make drivers
# !./benchmark.pl
# !./correctness.pl
# Out:
# ./gen-driver.pl -n 4 -f ncopy.ys > sdriver.ys
# ../misc/yas sdriver.ys
# ./gen-driver.pl -n 63 -f ncopy.ys > ldriver.ys
# ../misc/yas ldriver.ys
# 	ncopy
# 0	13
# 1	28	28.00
# 2	38	19.00
# 3	45	15.00
# 4	55	13.75
# 5	62	12.40
# 6	72	12.00
# 7	82	11.71
# 8	96	12.00
# 9	103	11.44
# 10	113	11.30
# 11	120	10.91
# 12	130	10.83
# 13	137	10.54
# 14	150	10.71
# 15	161	10.73
# 16	171	10.69
# 17	178	10.47
# 18	188	10.44
# 19	195	10.26
# 20	205	10.25
# 21	215	10.24
# 22	229	10.41
# 23	236	10.26
# 24	246	10.25
# 25	253	10.12
# 26	263	10.12
# 27	270	10.00
# 28	283	10.11
# 29	294	10.14
# 30	304	10.13
# 31	311	10.03
# 32	321	10.03
# 33	328	9.94
# 34	338	9.94
# 35	348	9.94
# 36	362	10.06
# 37	369	9.97
# 38	379	9.97
# 39	386	9.90
# 40	396	9.90
# 41	403	9.83
# 42	416	9.90
# 43	427	9.93
# 44	437	9.93
# 45	444	9.87
# 46	454	9.87
# 47	461	9.81
# 48	471	9.81
# 49	481	9.82
# 50	495	9.90
# 51	502	9.84
# 52	512	9.85
# 53	519	9.79
# 54	529	9.80
# 55	536	9.75
# 56	549	9.80
# 57	560	9.82
# 58	570	9.83
# ...

# %%
# !cp ncopy-copy-15.ys ncopy.ys
# !make drivers
# !./benchmark.pl
# !./correctness.pl
# Out:
# ./gen-driver.pl -n 4 -f ncopy.ys > sdriver.ys
# ../misc/yas sdriver.ys
# ./gen-driver.pl -n 63 -f ncopy.ys > ldriver.ys
# ../misc/yas ldriver.ys
# 	ncopy
# 0	12
# 1	36	36.00
# 2	43	21.50
# 3	45	15.00
# 4	54	13.50
# 5	56	11.20
# 6	63	10.50
# 7	65	9.29
# 8	86	10.75
# 9	88	9.78
# 10	95	9.50
# 11	97	8.82
# 12	106	8.83
# 13	108	8.31
# 14	115	8.21
# 15	117	7.80
# 16	134	8.38
# 17	136	8.00
# 18	143	7.94
# 19	145	7.63
# 20	154	7.70
# 21	156	7.43
# 22	163	7.41
# 23	165	7.17
# 24	182	7.58
# 25	184	7.36
# 26	191	7.35
# 27	193	7.15
# 28	202	7.21
# 29	204	7.03
# 30	211	7.03
# 31	213	6.87
# 32	230	7.19
# 33	232	7.03
# 34	239	7.03
# 35	241	6.89
# 36	250	6.94
# 37	252	6.81
# 38	259	6.82
# 39	261	6.69
# 40	278	6.95
# 41	280	6.83
# 42	287	6.83
# 43	289	6.72
# 44	298	6.77
# 45	300	6.67
# 46	307	6.67
# 47	309	6.57
# 48	326	6.79
# 49	328	6.69
# 50	335	6.70
# 51	337	6.61
# 52	346	6.65
# 53	348	6.57
# 54	355	6.57
# 55	357	6.49
# 56	374	6.68
# 57	376	6.60
# 58	383	6.60
# 59	385	6.53
# 60	394	6.57
# ...

# %%
# !cp ncopy-copy-17.ys ncopy.ys
# !make drivers
# !./benchmark.pl
# !./correctness.pl
# Out:
# ./gen-driver.pl -n 4 -f ncopy.ys > sdriver.ys
# ../misc/yas sdriver.ys
# ./gen-driver.pl -n 63 -f ncopy.ys > ldriver.ys
# ../misc/yas ldriver.ys
# 	ncopy
# 0	16
# 1	23	23.00
# 2	32	16.00
# 3	38	12.67
# 4	47	11.75
# 5	53	10.60
# 6	62	10.33
# 7	63	9.00
# 8	68	8.50
# 9	75	8.33
# 10	84	8.40
# 11	90	8.18
# 12	99	8.25
# 13	105	8.08
# 14	114	8.14
# 15	115	7.67
# 16	116	7.25
# 17	123	7.24
# 18	132	7.33
# 19	138	7.26
# 20	147	7.35
# 21	153	7.29
# 22	162	7.36
# 23	163	7.09
# 24	164	6.83
# 25	171	6.84
# 26	180	6.92
# 27	186	6.89
# 28	195	6.96
# 29	201	6.93
# 30	210	7.00
# 31	211	6.81
# 32	212	6.62
# 33	219	6.64
# 34	228	6.71
# 35	234	6.69
# 36	243	6.75
# 37	249	6.73
# 38	258	6.79
# 39	259	6.64
# 40	260	6.50
# 41	267	6.51
# 42	276	6.57
# 43	282	6.56
# 44	291	6.61
# 45	297	6.60
# 46	306	6.65
# 47	307	6.53
# 48	308	6.42
# 49	315	6.43
# 50	324	6.48
# 51	330	6.47
# 52	339	6.52
# 53	345	6.51
# 54	354	6.56
# 55	355	6.45
# 56	356	6.36
# 57	363	6.37
# 58	372	6.41
# 59	378	6.41
# 60	387	6.45
# ...
